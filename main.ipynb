# %% [markdown]
# # Загрузка данных из фотографии
#
# Файл загружается в database/Petr.npy

# %%
import cv2
import importlib
import utils
importlib.reload(utils)

imgage = cv2.imread('media/my_face.jpg')

utils.add_person([imgage], label="Petr")

# %% [markdown]
# # Определение лиц на видео
#
# Выводится евклидово расстояние между найденными векторами точек (оно большое)
#
# Можно нажать 'q', чтоб завершить выполнение

# %%
import importlib
import utils
importlib.reload(utils)

utils.detect_persons("media/my_face.mp4")
# Out:
# 712.7320674699574
# 776.9980694956713
# 815.6623075758743
# 982.8316234228527
# 1088.937096438541
# 1231.7787950764537
# 1415.2183577102157
# 1551.9790591370747
# 1750.4450862566355
# 1909.5360693110774
# 2083.3233066425382
# 2316.1698987768577
# 2507.556779018174
# 2670.2151598700807
# 2838.7587076044347
# 2966.6990073143584
# 3060.4731660316843
# 3148.0219186022196
# 3166.9846857855186
# 3177.5490554828575
# 3166.317577249635
# 3114.2369852019933
# 3033.7554285077103
# 2937.969196570992
# 2840.8836653407684
# 2712.521336321615
# 2551.651230086118
# 2410.950227607364
# 2256.5353974622244
# 2104.8016533630907
# 1979.746195854408
# 1867.588819842312
# 1786.518401808389
# 1720.0933114223774
# 1632.2221049844902
# 1601.7580965926159
# 1546.5458286129124
# 1519.1553574272777
# 1442.6174128992066
# 1381.6645757925473
# 1412.8418170481789
# 1382.142901439645
# 1376.8925157760136
# 1554.1566845077107
# 1634.4011135581131
# 1671.0505677567032
# 1661.2940739074463
# 1547.89437624148
# ...
